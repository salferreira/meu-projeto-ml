# %% [markdown]
# <a href="https://colab.research.google.com/github/salferreira/meu-rpojeto-ml/blob/main/Aula1409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Projeto de Aula**

# %% [markdown]
# **1. Importando bibliotecas inciais**

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# **2. Importando e Carregando o Dados**

# %%
from google.colab import drive
import pandas as pd # Importar a biblioteca pandas

drive.mount('/content/drive')   # Monta o Drive

# df = load_dataset("/content/drive/MyDrive/CETAM/LLM")
df = pd.read_csv("/content/drive/MyDrive/CETAM/LLM/amazon_review_sa_binary_csv/train.csv")   # Carrega a base de dados para df usando pandas

print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          class_index                                       review_title  \
# 0                  2                     Stuning even for the non-gamer
# 1                  2              The best soundtrack ever to anything.
# 2                  2                                           Amazing!
# 3                  2                               Excellent Soundtrack
# 4                  2  Remember, Pull Your Jaw Off The Floor After He...
# ...              ...                                                ...
# 3599995            1                                      Don't do it!!
# 3599996            1                      Looks nice, low functionality
# 3599997            1                         compact, but hard to clean
# 3599998            1                                 what is it saying?
# ...

# %% [markdown]
# **3. Separando a amostragem de teste e treino**

# %%
import os

folder_path = "/content/drive/MyDrive/CETAM/LLM/amazon_review_sa_binary_csv"
print(f"Contents of {folder_path}:")
for item in os.listdir(folder_path):
    print(item)
# Out:
# Contents of /content/drive/MyDrive/CETAM/LLM/amazon_review_sa_binary_csv:
# readme.txt
# test.csv
# train.csv

# %% [markdown]
# **4. Parametros de treinamento**

# %%
SEED = 42
np.random.seed(SEED)

# Assuming the first column is features (X) and the second is the target (y)
# Adjust column indices or names if your CSV has a different structure.
X = df.iloc[:, 0]  # Features
y = df.iloc[:, 1]  # Target

# sklearn
model = RandomForestClassifier(random_state=SEED)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=SEED)
